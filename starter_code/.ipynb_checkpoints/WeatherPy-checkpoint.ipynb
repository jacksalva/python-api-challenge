# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import date

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

#counter
i = 1

#Lists for dataframe
cityName = []
lat = []
lng = []
temp = []
humid = []
clouds = []
wind = []

#Loop through each city
print("Beginning Data Retrieval")
print('------------------------------')

for city in cities:
    try:
        request = (requests.get(f"{url}appid={weather_api_key}&units={units}&q={city}")).json()
        cityName.append(request['name'])
        lat.append(request['coord']['lat'])
        lng.append(request['coord']['lon'])
        temp.append(request['main']['temp'])
        humid.append(request['main']['humidity'])
        clouds.append(request['clouds']['all'])
        wind.append(request['wind']['speed'])
        print(f'Processing Record {i} of Set {len(cities)}. | {city}')
        i += 1
    
    except KeyError:
        print(f'City not found. Skipping {city}...')
        i += 1
        
print('------------------------------')
print('Data Retrieval Complete')
print('------------------------------')
# Out:
# Beginning Data Retrieval
# ------------------------------
# City not found. Skipping tsihombe...
# Processing Record 2 of Set 620. | barrow
# Processing Record 3 of Set 620. | thompson
# Processing Record 4 of Set 620. | mataura
# Processing Record 5 of Set 620. | lompoc
# Processing Record 6 of Set 620. | khatanga
# Processing Record 7 of Set 620. | matagami
# Processing Record 8 of Set 620. | hambantota
# Processing Record 9 of Set 620. | kuruman
# Processing Record 10 of Set 620. | mogadishu
# Processing Record 11 of Set 620. | victoria
# Processing Record 12 of Set 620. | namibe
# Processing Record 13 of Set 620. | tarpon springs
# Processing Record 14 of Set 620. | manta
# Processing Record 15 of Set 620. | kasongo
# Processing Record 16 of Set 620. | chokurdakh
# Processing Record 17 of Set 620. | masterton
# Processing Record 18 of Set 620. | cape town
# Processing Record 19 of Set 620. | dingle
# Processing Record 20 of Set 620. | moranbah
# Processing Record 21 of Set 620. | namatanai
# Processing Record 22 of Set 620. | mokhsogollokh
# Processing Record 23 of Set 620. | vaini
# Processing Record 24 of Set 620. | kamenka
# Processing Record 25 of Set 620. | kodiak
# Processing Record 26 of Set 620. | vaitape
# Processing Record 27 of Set 620. | sabang
# Processing Record 28 of Set 620. | dimitrovgrad
# Processing Record 29 of Set 620. | tomatlan
# Processing Record 30 of Set 620. | rikitea
# Processing Record 31 of Set 620. | blackwater
# Processing Record 32 of Set 620. | puerto escondido
# Processing Record 33 of Set 620. | castro
# Processing Record 34 of Set 620. | arraial do cabo
# Processing Record 35 of Set 620. | yumen
# Processing Record 36 of Set 620. | gigmoto
# Processing Record 37 of Set 620. | mezhdurechensk
# Processing Record 38 of Set 620. | mar del plata
# Processing Record 39 of Set 620. | saint george
# City not found. Skipping tumannyy...
# Processing Record 41 of Set 620. | warner robins
# Processing Record 42 of Set 620. | jizan
# Processing Record 43 of Set 620. | tiquisate
# Processing Record 44 of Set 620. | albany
# Processing Record 45 of Set 620. | bheramara
# City not found. Skipping belushya guba...
# Processing Record 47 of Set 620. | yellowknife
# Processing Record 48 of Set 620. | glinka
# Processing Record 49 of Set 620. | oranjemund
# Processing Record 50 of Set 620. | kokemaki
# Processing Record 51 of Set 620. | hermanus
# Processing Record 52 of Set 620. | punta arenas
# Processing Record 53 of Set 620. | noumea
# Processing Record 54 of Set 620. | ushuaia
# City not found. Skipping taburi...
# Processing Record 56 of Set 620. | tuktoyaktuk
# Processing Record 57 of Set 620. | nishihara
# Processing Record 58 of Set 620. | mahanje
# City not found. Skipping rawannawi...
# Processing Record 60 of Set 620. | garoua
# City not found. Skipping barentsburg...
# Processing Record 62 of Set 620. | san quintin
# City not found. Skipping taolanaro...
# Processing Record 64 of Set 620. | fortuna
# Processing Record 65 of Set 620. | bluff
# Processing Record 66 of Set 620. | ponta do sol
# Processing Record 67 of Set 620. | pemangkat
# City not found. Skipping jiddah...
# Processing Record 69 of Set 620. | portland
# City not found. Skipping illoqqortoormiut...
# Processing Record 71 of Set 620. | atuona
# Processing Record 72 of Set 620. | lagoa
# Processing Record 73 of Set 620. | bredasdorp
# Processing Record 74 of Set 620. | faanui
# Processing Record 75 of Set 620. | lebu
# Processing Record 76 of Set 620. | ancud
# Processing Record 77 of Set 620. | san juan de colon
# Processing Record 78 of Set 620. | saint anthony
# City not found. Skipping marcona...
# City not found. Skipping amderma...
# Processing Record 81 of Set 620. | provideniya
# Processing Record 82 of Set 620. | hobart
# Processing Record 83 of Set 620. | bambous virieux
# Processing Record 84 of Set 620. | quatre cocos
# Processing Record 85 of Set 620. | komsomolskiy
# Processing Record 86 of Set 620. | benin
# Processing Record 87 of Set 620. | aksehir
# Processing Record 88 of Set 620. | buenos aires
# Processing Record 89 of Set 620. | mount gambier
# Processing Record 90 of Set 620. | saint-philippe
# Processing Record 91 of Set 620. | iqaluit
# Processing Record 92 of Set 620. | ossora
# Processing Record 93 of Set 620. | oudtshoorn
# Processing Record 94 of Set 620. | lulea
# Processing Record 95 of Set 620. | busselton
# Processing Record 96 of Set 620. | nikel
# Processing Record 97 of Set 620. | mahebourg
# Processing Record 98 of Set 620. | tikhvin
# Processing Record 99 of Set 620. | muisne
# Processing Record 100 of Set 620. | paracuru
# Processing Record 101 of Set 620. | nelson bay
# Processing Record 102 of Set 620. | anadyr
# Processing Record 103 of Set 620. | alofi
# Processing Record 104 of Set 620. | geraldton
# City not found. Skipping louisbourg...
# Processing Record 106 of Set 620. | nikolskoye
# Processing Record 107 of Set 620. | qaanaaq
# Processing Record 108 of Set 620. | shimoda
# Processing Record 109 of Set 620. | poronaysk
# Processing Record 110 of Set 620. | port alfred
# Processing Record 111 of Set 620. | iranduba
# Processing Record 112 of Set 620. | xining
# Processing Record 113 of Set 620. | diego de almagro
# Processing Record 114 of Set 620. | dzilam gonzalez
# Processing Record 115 of Set 620. | korla
# Processing Record 116 of Set 620. | iguala
# Processing Record 117 of Set 620. | vardo
# Processing Record 118 of Set 620. | new norfolk
# Processing Record 119 of Set 620. | kodinsk
# Processing Record 120 of Set 620. | carnarvon
# Processing Record 121 of Set 620. | rawson
# Processing Record 122 of Set 620. | cidreira
# Processing Record 123 of Set 620. | svetlogorsk
# Processing Record 124 of Set 620. | tiarei
# Processing Record 125 of Set 620. | college
# Processing Record 126 of Set 620. | stephenville crossing
# Processing Record 127 of Set 620. | avarua
# City not found. Skipping mys shmidta...
# Processing Record 129 of Set 620. | mercedes
# Processing Record 130 of Set 620. | turayf
# Processing Record 131 of Set 620. | north platte
# Processing Record 132 of Set 620. | antofagasta
# Processing Record 133 of Set 620. | ilulissat
# Processing Record 134 of Set 620. | ibra
# Processing Record 135 of Set 620. | klaksvik
# Processing Record 136 of Set 620. | arrifes
# City not found. Skipping karkaralinsk...
# Processing Record 138 of Set 620. | ormara
# Processing Record 139 of Set 620. | nome
# Processing Record 140 of Set 620. | georgetown
# Processing Record 141 of Set 620. | hithadhoo
# Processing Record 142 of Set 620. | tarakan
# Processing Record 143 of Set 620. | comodoro rivadavia
# Processing Record 144 of Set 620. | trairi
# Processing Record 145 of Set 620. | mbanza-ngungu
# Processing Record 146 of Set 620. | pisco
# City not found. Skipping toliary...
# Processing Record 148 of Set 620. | tiksi
# Processing Record 149 of Set 620. | poum
# Processing Record 150 of Set 620. | touros
# Processing Record 151 of Set 620. | butaritari
# Processing Record 152 of Set 620. | chalons-en-champagne
# Processing Record 153 of Set 620. | port elizabeth
# Processing Record 154 of Set 620. | paita
# City not found. Skipping lolua...
# Processing Record 156 of Set 620. | peniche
# Processing Record 157 of Set 620. | benicarlo
# Processing Record 158 of Set 620. | olinda
# Processing Record 159 of Set 620. | puerto ayora
# Processing Record 160 of Set 620. | ponta delgada
# Processing Record 161 of Set 620. | okha
# Processing Record 162 of Set 620. | kruisfontein
# Processing Record 163 of Set 620. | kismayo
# Processing Record 164 of Set 620. | villamontes
# Processing Record 165 of Set 620. | tautira
# Processing Record 166 of Set 620. | plotnikovo
# Processing Record 167 of Set 620. | kosa
# Processing Record 168 of Set 620. | koslan
# Processing Record 169 of Set 620. | kapaa
# Processing Record 170 of Set 620. | abu samrah
# Processing Record 171 of Set 620. | severo-kurilsk
# Processing Record 172 of Set 620. | novoye leushino
# Processing Record 173 of Set 620. | tzucacab
# Processing Record 174 of Set 620. | bengkulu
# Processing Record 175 of Set 620. | goose creek
# Processing Record 176 of Set 620. | belyy yar
# Processing Record 177 of Set 620. | tecoanapa
# Processing Record 178 of Set 620. | eyl
# Processing Record 179 of Set 620. | noshiro
# Processing Record 180 of Set 620. | nanortalik
# Processing Record 181 of Set 620. | berlevag
# Processing Record 182 of Set 620. | banda aceh
# Processing Record 183 of Set 620. | pachino
# Processing Record 184 of Set 620. | abonnema
# Processing Record 185 of Set 620. | whitecourt
# Processing Record 186 of Set 620. | zhezkazgan
# Processing Record 187 of Set 620. | baykit
# Processing Record 188 of Set 620. | pevek
# Processing Record 189 of Set 620. | muzhi
# Processing Record 190 of Set 620. | berbera
# Processing Record 191 of Set 620. | san ignacio
# Processing Record 192 of Set 620. | high river
# City not found. Skipping sentyabrskiy...
# Processing Record 194 of Set 620. | devonport
# Processing Record 195 of Set 620. | upernavik
# Processing Record 196 of Set 620. | two rivers
# Processing Record 197 of Set 620. | inirida
# Processing Record 198 of Set 620. | el dorado
# City not found. Skipping gurskoye...
# Processing Record 200 of Set 620. | vibo valentia
# Processing Record 201 of Set 620. | keetmanshoop
# Processing Record 202 of Set 620. | yenagoa
# Processing Record 203 of Set 620. | liverpool
# Processing Record 204 of Set 620. | tongren
# Processing Record 205 of Set 620. | tshikapa
# Processing Record 206 of Set 620. | saint-gabriel
# Processing Record 207 of Set 620. | seymchan
# Processing Record 208 of Set 620. | bethel
# Processing Record 209 of Set 620. | east london
# Processing Record 210 of Set 620. | kamiichi
# Processing Record 211 of Set 620. | jamestown
# Processing Record 212 of Set 620. | san cristobal
# Processing Record 213 of Set 620. | tawang
# Processing Record 214 of Set 620. | ust-maya
# Processing Record 215 of Set 620. | fukue
# Processing Record 216 of Set 620. | stolin
# Processing Record 217 of Set 620. | okhotsk
# Processing Record 218 of Set 620. | dawson creek
# Processing Record 219 of Set 620. | bella union
# Processing Record 220 of Set 620. | ribeira grande
# Processing Record 221 of Set 620. | mackenzie
# Processing Record 222 of Set 620. | luderitz
# Processing Record 223 of Set 620. | cotacachi
# Processing Record 224 of Set 620. | bathurst
# Processing Record 225 of Set 620. | tuatapere
# Processing Record 226 of Set 620. | kahului
# Processing Record 227 of Set 620. | adrar
# City not found. Skipping nizhneyansk...
# Processing Record 229 of Set 620. | katherine
# Processing Record 230 of Set 620. | ferkessedougou
# Processing Record 231 of Set 620. | karratha
# Processing Record 232 of Set 620. | bayonet point
# Processing Record 233 of Set 620. | yulara
# Processing Record 234 of Set 620. | kenai
# Processing Record 235 of Set 620. | nogliki
# Processing Record 236 of Set 620. | thunder bay
# Processing Record 237 of Set 620. | esperance
# Processing Record 238 of Set 620. | te anau
# Processing Record 239 of Set 620. | lourdes
# Processing Record 240 of Set 620. | nuuk
# City not found. Skipping grand river south east...
# Processing Record 242 of Set 620. | saint-pierre
# Processing Record 243 of Set 620. | ahipara
# Processing Record 244 of Set 620. | aklera
# Processing Record 245 of Set 620. | tasiilaq
# Processing Record 246 of Set 620. | uusikaupunki
# Processing Record 247 of Set 620. | havre-saint-pierre
# Processing Record 248 of Set 620. | sioux lookout
# Processing Record 249 of Set 620. | santa vitoria do palmar
# Processing Record 250 of Set 620. | sobolevo
# Processing Record 251 of Set 620. | yanji
# Processing Record 252 of Set 620. | mocuba
# Processing Record 253 of Set 620. | clyde river
# Processing Record 254 of Set 620. | port lincoln
# Processing Record 255 of Set 620. | biak
# Processing Record 256 of Set 620. | chardara
# Processing Record 257 of Set 620. | chernyshevskiy
# Processing Record 258 of Set 620. | alamosa
# Processing Record 259 of Set 620. | norman wells
# Processing Record 260 of Set 620. | inuvik
# Processing Record 261 of Set 620. | kunyang
# Processing Record 262 of Set 620. | longyearbyen
# Processing Record 263 of Set 620. | souillac
# Processing Record 264 of Set 620. | codrington
# Processing Record 265 of Set 620. | chernyshevsk
# City not found. Skipping umzimvubu...
# City not found. Skipping artyk...
# Processing Record 268 of Set 620. | nampula
# Processing Record 269 of Set 620. | hualmay
# Processing Record 270 of Set 620. | pangnirtung
# Processing Record 271 of Set 620. | kwinana
# Processing Record 272 of Set 620. | isangel
# City not found. Skipping kerteh...
# City not found. Skipping shchelyayur...
# Processing Record 275 of Set 620. | halifax
# Processing Record 276 of Set 620. | serenje
# Processing Record 277 of Set 620. | along
# City not found. Skipping hai phong...
# Processing Record 279 of Set 620. | aykhal
# Processing Record 280 of Set 620. | mudon
# Processing Record 281 of Set 620. | sitka
# City not found. Skipping bolungarvik...
# Processing Record 283 of Set 620. | bamiantong
# Processing Record 284 of Set 620. | hilo
# Processing Record 285 of Set 620. | yarensk
# Processing Record 286 of Set 620. | bay-khaak
# Processing Record 287 of Set 620. | forio
# Processing Record 288 of Set 620. | meulaboh
# City not found. Skipping matsanga...
# Processing Record 290 of Set 620. | thinadhoo
# Processing Record 291 of Set 620. | cabo san lucas
# Processing Record 292 of Set 620. | kapit
# Processing Record 293 of Set 620. | cherskiy
# Processing Record 294 of Set 620. | shache
# Processing Record 295 of Set 620. | araouane
# Processing Record 296 of Set 620. | lavrentiya
# Processing Record 297 of Set 620. | mecca
# Processing Record 298 of Set 620. | nortelandia
# Processing Record 299 of Set 620. | shirokiy
# Processing Record 300 of Set 620. | sandwick
# Processing Record 301 of Set 620. | svetlaya
# Processing Record 302 of Set 620. | aksarka
# Processing Record 303 of Set 620. | yarmouth
# Processing Record 304 of Set 620. | nouadhibou
# Processing Record 305 of Set 620. | manggar
# Processing Record 306 of Set 620. | zaporizhzhya
# Processing Record 307 of Set 620. | salalah
# Processing Record 308 of Set 620. | monrovia
# Processing Record 309 of Set 620. | mount isa
# Processing Record 310 of Set 620. | lorengau
# Processing Record 311 of Set 620. | tchollire
# City not found. Skipping napaliran...
# Processing Record 313 of Set 620. | lasa
# Processing Record 314 of Set 620. | santa maria
# Processing Record 315 of Set 620. | brufut
# Processing Record 316 of Set 620. | airai
# Processing Record 317 of Set 620. | kurumkan
# Processing Record 318 of Set 620. | weiser
# Processing Record 319 of Set 620. | gorom-gorom
# Processing Record 320 of Set 620. | harbour breton
# Processing Record 321 of Set 620. | iskateley
# Processing Record 322 of Set 620. | waingapu
# Processing Record 323 of Set 620. | liberal
# Processing Record 324 of Set 620. | asau
# City not found. Skipping kamenskoye...
# Processing Record 326 of Set 620. | luwuk
# Processing Record 327 of Set 620. | tafresh
# Processing Record 328 of Set 620. | sinnamary
# Processing Record 329 of Set 620. | esil
# Processing Record 330 of Set 620. | gamboma
# Processing Record 331 of Set 620. | barsovo
# Processing Record 332 of Set 620. | umm kaddadah
# Processing Record 333 of Set 620. | vila velha
# City not found. Skipping bolshiye uki...
# Processing Record 335 of Set 620. | tudela
# Processing Record 336 of Set 620. | samarai
# Processing Record 337 of Set 620. | parauna
# Processing Record 338 of Set 620. | laguna
# Processing Record 339 of Set 620. | sao joao da barra
# Processing Record 340 of Set 620. | domoni
# City not found. Skipping attawapiskat...
# Processing Record 342 of Set 620. | kalashnikovo
# City not found. Skipping falealupo...
# Processing Record 344 of Set 620. | vila franca do campo
# Processing Record 345 of Set 620. | honiara
# Processing Record 346 of Set 620. | williston
# Processing Record 347 of Set 620. | olavarria
# City not found. Skipping scottsburgh...
# Processing Record 349 of Set 620. | urumqi
# Processing Record 350 of Set 620. | guerrero negro
# Processing Record 351 of Set 620. | dikson
# Processing Record 352 of Set 620. | yeniseysk
# Processing Record 353 of Set 620. | bonavista
# Processing Record 354 of Set 620. | lubu
# Processing Record 355 of Set 620. | santa rosa
# Processing Record 356 of Set 620. | la asuncion
# Processing Record 357 of Set 620. | butgenbach
# Processing Record 358 of Set 620. | cayenne
# Processing Record 359 of Set 620. | coihaique
# Processing Record 360 of Set 620. | barcelos
# Processing Record 361 of Set 620. | san patricio
# Processing Record 362 of Set 620. | pipirig
# Processing Record 363 of Set 620. | coos bay
# Processing Record 364 of Set 620. | santa fe
# Processing Record 365 of Set 620. | yerbogachen
# Processing Record 366 of Set 620. | agadez
# City not found. Skipping teneguiban...
# Processing Record 368 of Set 620. | alta floresta
# Processing Record 369 of Set 620. | cururupu
# Processing Record 370 of Set 620. | torbay
# Processing Record 371 of Set 620. | alapur
# Processing Record 372 of Set 620. | vredendal
# Processing Record 373 of Set 620. | mandalgovi
# Processing Record 374 of Set 620. | taksimo
# Processing Record 375 of Set 620. | ust-ilimsk
# Processing Record 376 of Set 620. | salto
# Processing Record 377 of Set 620. | grindavik
# Processing Record 378 of Set 620. | fairbanks
# City not found. Skipping meyungs...
# Processing Record 380 of Set 620. | barbastro
# Processing Record 381 of Set 620. | muros
# Processing Record 382 of Set 620. | bodden town
# Processing Record 383 of Set 620. | prattville
# Processing Record 384 of Set 620. | broome
# Processing Record 385 of Set 620. | parrita
# Processing Record 386 of Set 620. | kangasala
# Processing Record 387 of Set 620. | xiaoweizhai
# Processing Record 388 of Set 620. | batemans bay
# Processing Record 389 of Set 620. | marawi
# Processing Record 390 of Set 620. | chuy
# Processing Record 391 of Set 620. | bereda
# Processing Record 392 of Set 620. | pochutla
# Processing Record 393 of Set 620. | aklavik
# Processing Record 394 of Set 620. | ellensburg
# Processing Record 395 of Set 620. | rio grande
# Processing Record 396 of Set 620. | beboto
# Processing Record 397 of Set 620. | bangangte
# Processing Record 398 of Set 620. | hanzhong
# Processing Record 399 of Set 620. | beringovskiy
# Processing Record 400 of Set 620. | saskylakh
# Processing Record 401 of Set 620. | kalmunai
# Processing Record 402 of Set 620. | aripuana
# Processing Record 403 of Set 620. | chipiona
# Processing Record 404 of Set 620. | beyneu
# Processing Record 405 of Set 620. | casma
# Processing Record 406 of Set 620. | kidal
# Processing Record 407 of Set 620. | jalu
# Processing Record 408 of Set 620. | zelenoborskiy
# Processing Record 409 of Set 620. | santo domingo
# Processing Record 410 of Set 620. | batagay-alyta
# Processing Record 411 of Set 620. | opuwo
# Processing Record 412 of Set 620. | gorontalo
# Processing Record 413 of Set 620. | ippy
# Processing Record 414 of Set 620. | amahai
# Processing Record 415 of Set 620. | karpathos
# City not found. Skipping haibowan...
# Processing Record 417 of Set 620. | kushmurun
# Processing Record 418 of Set 620. | barra patuca
# Processing Record 419 of Set 620. | hay river
# Processing Record 420 of Set 620. | bachaquero
# Processing Record 421 of Set 620. | morant bay
# Processing Record 422 of Set 620. | zhangye
# Processing Record 423 of Set 620. | tateyama
# Processing Record 424 of Set 620. | zyryanka
# Processing Record 425 of Set 620. | musafirkhana
# Processing Record 426 of Set 620. | billings
# Processing Record 427 of Set 620. | vestmanna
# Processing Record 428 of Set 620. | coquimbo
# Processing Record 429 of Set 620. | lar
# City not found. Skipping vaitupu...
# Processing Record 431 of Set 620. | surab
# Processing Record 432 of Set 620. | gat
# Processing Record 433 of Set 620. | kaitangata
# Processing Record 434 of Set 620. | warrington
# Processing Record 435 of Set 620. | samana
# Processing Record 436 of Set 620. | salinas
# Processing Record 437 of Set 620. | fatehpur
# Processing Record 438 of Set 620. | bam
# Processing Record 439 of Set 620. | arosa
# Processing Record 440 of Set 620. | obo
# Processing Record 441 of Set 620. | avera
# Processing Record 442 of Set 620. | tezu
# Processing Record 443 of Set 620. | formosa
# Processing Record 444 of Set 620. | saint-leu
# Processing Record 445 of Set 620. | athabasca
# Processing Record 446 of Set 620. | hella
# Processing Record 447 of Set 620. | christchurch
# Processing Record 448 of Set 620. | sibu
# Processing Record 449 of Set 620. | pimentel
# Processing Record 450 of Set 620. | north bend
# Processing Record 451 of Set 620. | wanning
# Processing Record 452 of Set 620. | zverinogolovskoye
# Processing Record 453 of Set 620. | rawlins
# Processing Record 454 of Set 620. | ullapool
# City not found. Skipping babanusah...
# Processing Record 456 of Set 620. | polunochnoye
# Processing Record 457 of Set 620. | taltal
# Processing Record 458 of Set 620. | shinpokh
# Processing Record 459 of Set 620. | buchanan
# Processing Record 460 of Set 620. | pyshma
# Processing Record 461 of Set 620. | port-gentil
# Processing Record 462 of Set 620. | telfs
# Processing Record 463 of Set 620. | probolinggo
# City not found. Skipping sungai kolok...
# Processing Record 465 of Set 620. | sozimskiy
# City not found. Skipping phan rang...
# Processing Record 467 of Set 620. | conceicao da barra
# Processing Record 468 of Set 620. | tessalit
# Processing Record 469 of Set 620. | husavik
# Processing Record 470 of Set 620. | pemberton
# Processing Record 471 of Set 620. | sept-iles
# Processing Record 472 of Set 620. | seabrook
# Processing Record 473 of Set 620. | tabuk
# Processing Record 474 of Set 620. | surt
# Processing Record 475 of Set 620. | fare
# Processing Record 476 of Set 620. | tahara
# Processing Record 477 of Set 620. | amapa
# Processing Record 478 of Set 620. | lunglei
# Processing Record 479 of Set 620. | millau
# Processing Record 480 of Set 620. | escanaba
# Processing Record 481 of Set 620. | arica
# Processing Record 482 of Set 620. | sembakung
# Processing Record 483 of Set 620. | hamilton
# City not found. Skipping palabuhanratu...
# Processing Record 485 of Set 620. | narsaq
# Processing Record 486 of Set 620. | sudogda
# City not found. Skipping ruatoria...
# Processing Record 488 of Set 620. | mitsamiouli
# Processing Record 489 of Set 620. | areka
# City not found. Skipping samusu...
# Processing Record 491 of Set 620. | yalta
# Processing Record 492 of Set 620. | mahina
# Processing Record 493 of Set 620. | kupang
# Processing Record 494 of Set 620. | kandiari
# Processing Record 495 of Set 620. | teahupoo
# Processing Record 496 of Set 620. | rundu
# Processing Record 497 of Set 620. | hami
# Processing Record 498 of Set 620. | manicore
# Processing Record 499 of Set 620. | roald
# Processing Record 500 of Set 620. | mayumba
# Processing Record 501 of Set 620. | rethimnon
# Processing Record 502 of Set 620. | sur
# Processing Record 503 of Set 620. | chizhou
# Processing Record 504 of Set 620. | talnakh
# Processing Record 505 of Set 620. | garowe
# Processing Record 506 of Set 620. | dongying
# Processing Record 507 of Set 620. | hibbing
# Processing Record 508 of Set 620. | sola
# Processing Record 509 of Set 620. | tarbagatay
# Processing Record 510 of Set 620. | pasni
# Processing Record 511 of Set 620. | tigil
# Processing Record 512 of Set 620. | shetpe
# Processing Record 513 of Set 620. | mwinilunga
# Processing Record 514 of Set 620. | raudeberg
# Processing Record 515 of Set 620. | barranca
# Processing Record 516 of Set 620. | bubaque
# Processing Record 517 of Set 620. | itapora
# Processing Record 518 of Set 620. | canaries
# Processing Record 519 of Set 620. | ankang
# Processing Record 520 of Set 620. | acapulco
# Processing Record 521 of Set 620. | bousse
# Processing Record 522 of Set 620. | morondava
# Processing Record 523 of Set 620. | tual
# Processing Record 524 of Set 620. | asfi
# City not found. Skipping kuche...
# Processing Record 526 of Set 620. | olafsvik
# Processing Record 527 of Set 620. | bougouni
# Processing Record 528 of Set 620. | la libertad
# City not found. Skipping nguiu...
# Processing Record 530 of Set 620. | arlit
# Processing Record 531 of Set 620. | altamira
# Processing Record 532 of Set 620. | shreveport
# Processing Record 533 of Set 620. | progress
# Processing Record 534 of Set 620. | marquette
# Processing Record 535 of Set 620. | polovinnoye
# Processing Record 536 of Set 620. | lerwick
# Processing Record 537 of Set 620. | obregon
# Processing Record 538 of Set 620. | krasnoselkup
# City not found. Skipping buqayq...
# Processing Record 540 of Set 620. | richards bay
# Processing Record 541 of Set 620. | laredo
# Processing Record 542 of Set 620. | dabat
# Processing Record 543 of Set 620. | mango
# Processing Record 544 of Set 620. | margate
# Processing Record 545 of Set 620. | atherton
# City not found. Skipping fort saint john...
# Processing Record 547 of Set 620. | makakilo city
# Processing Record 548 of Set 620. | finschhafen
# Processing Record 549 of Set 620. | vila do maio
# Processing Record 550 of Set 620. | tukrah
# Processing Record 551 of Set 620. | manokwari
# Processing Record 552 of Set 620. | qaqortoq
# Processing Record 553 of Set 620. | san joaquin
# Processing Record 554 of Set 620. | wazirganj
# Processing Record 555 of Set 620. | mayo
# Processing Record 556 of Set 620. | tarsus
# Processing Record 557 of Set 620. | vostok
# Processing Record 558 of Set 620. | lugovoy
# Processing Record 559 of Set 620. | chaoyang
# Processing Record 560 of Set 620. | baglung
# Processing Record 561 of Set 620. | bathsheba
# Processing Record 562 of Set 620. | dzerzhinsk
# Processing Record 563 of Set 620. | ostroda
# Processing Record 564 of Set 620. | wairoa
# Processing Record 565 of Set 620. | innoshima
# Processing Record 566 of Set 620. | tatawin
# Processing Record 567 of Set 620. | kawalu
# City not found. Skipping warqla...
# Processing Record 569 of Set 620. | la ronge
# Processing Record 570 of Set 620. | labuan
# Processing Record 571 of Set 620. | haines junction
# Processing Record 572 of Set 620. | gold coast
# Processing Record 573 of Set 620. | viedma
# Processing Record 574 of Set 620. | bilibino
# Processing Record 575 of Set 620. | ostrovnoy
# Processing Record 576 of Set 620. | kavieng
# Processing Record 577 of Set 620. | soyo
# City not found. Skipping utiroa...
# Processing Record 579 of Set 620. | santa marta
# City not found. Skipping ondorhaan...
# Processing Record 581 of Set 620. | morro bay
# Processing Record 582 of Set 620. | mareeba
# Processing Record 583 of Set 620. | shushtar
# Processing Record 584 of Set 620. | palmer
# Processing Record 585 of Set 620. | rosarito
# Processing Record 586 of Set 620. | brae
# Processing Record 587 of Set 620. | encruzilhada
# Processing Record 588 of Set 620. | hofn
# Processing Record 589 of Set 620. | poputnaya
# Processing Record 590 of Set 620. | padang
# Processing Record 591 of Set 620. | nakamura
# Processing Record 592 of Set 620. | rorvik
# Processing Record 593 of Set 620. | sribne
# Processing Record 594 of Set 620. | hasaki
# Processing Record 595 of Set 620. | katsuura
# Processing Record 596 of Set 620. | lielvarde
# Processing Record 597 of Set 620. | paris
# Processing Record 598 of Set 620. | ust-kuyga
# Processing Record 599 of Set 620. | ibotirama
# Processing Record 600 of Set 620. | biltine
# Processing Record 601 of Set 620. | tall kayf
# Processing Record 602 of Set 620. | axim
# Processing Record 603 of Set 620. | catuday
# Processing Record 604 of Set 620. | saldanha
# Processing Record 605 of Set 620. | usinsk
# Processing Record 606 of Set 620. | ulladulla
# Processing Record 607 of Set 620. | zonguldak
# Processing Record 608 of Set 620. | abha
# Processing Record 609 of Set 620. | zheleznodorozhnyy
# Processing Record 610 of Set 620. | smithers
# Processing Record 611 of Set 620. | kalamazoo
# Processing Record 612 of Set 620. | aksu
# Processing Record 613 of Set 620. | brandon
# Processing Record 614 of Set 620. | bandar-e lengeh
# City not found. Skipping formoso do araguaia...
# Processing Record 616 of Set 620. | salinopolis
# Processing Record 617 of Set 620. | constitucion
# Processing Record 618 of Set 620. | burgeo
# Processing Record 619 of Set 620. | hatta
# Processing Record 620 of Set 620. | gangapur
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Create a dataframe
city_data_df = pd.DataFrame({'City': cityName,
                            'Latitude': lat,
                            'Longitude': lng,
                            'Temperature': temp,
                            'Humidity': humid,
                            'Cloudiness': clouds,
                            'Wind Speed': wind})

#Save dataframe as csv
pd.DataFrame.to_csv(city_data_df, 'city_data.csv')

city_data_df.head()
# Out:
#        City  Latitude  Longitude  Temperature  Humidity  Cloudiness  \
# 0    Barrow     71.29    -156.79       -18.00        77          90
# 1  Thompson     55.74     -97.86       -26.00        68           5
# 2   Mataura    -46.19     168.86        13.33        98         100
# 3    Lompoc     34.64    -120.46         9.49       100          40
# 4  Khatanga     71.97     102.50       -38.18        98           2
#
#    Wind Speed
# 0        2.10
# 1        3.60
# 2        1.34
# 3        3.10
# 4        3.15

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(city_data_df['Latitude'], city_data_df['Temperature'])
plt.title(f'City Latitude vs. Temperature {date.today()}')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.grid(True)
plt.savefig('lat_temp.png', bbox_inches='tight')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(city_data_df['Latitude'], city_data_df['Humidity'])
plt.title(f'City Latitude vs. Humidity {date.today()}')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)
plt.savefig('lat_humid.png', bbox_inches='tight')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data_df['Latitude'], city_data_df['Cloudiness'])
plt.title(f'City Latitude vs. Cloudiness {date.today()}')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)
plt.savefig('lat_cloud.png', bbox_inches='tight')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data_df['Latitude'], city_data_df['Wind Speed'])
plt.title(f'City Latitude vs. Wind Speed {date.today()}')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)
plt.savefig('lat_wind.png', bbox_inches='tight')

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
